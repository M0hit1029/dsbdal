# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score

# load
df = pd.read_csv('./datasets/Hepatitis/hepatitis.csv')

# #replace the ? with na
# df = df.replace('?',np.nan)
# df = df.dropna(axis=0)

# cat_cols = [
#     'sex','steroid','antivirals','fatigue','malaise',
#     'anorexia','liver_big','liver_firm','spleen_palpable',
#     'spiders','ascites','varices','histology'
# ]

# num_cols = ['age','bilirubin','alk_phosphatase','sgot','albumin','protime']

# for c in num_cols:
#     df[c] = pd.to_numeric(df[c],errors="coerce")

# q1 = df[num_cols].quantile(0.25)
# q3 = df[num_cols].quantile(0.75)
# iqr = q3 - q1
# lb = q1 - (1.5*iqr)
# ub = q3 + (1.5*iqr)
# df = df[((df[num_cols] <= ub) & (df[num_cols] >= lb)).all(axis=1)]

# X = df.drop('class',axis=1)
# y = df['class']
# X_train,X_test,y_train,y_test = train_test_split(X,y,random_state=42,train_size=0.2)
# lg = LogisticRegression(max_iter=1000)
# lg.fit(X_train,y_train)
# y_pred = lg.predict(X_test)
# print(accuracy_score(y_test,y_pred))

df_male = df[df["sex"] == 1]
df_female = df[df["sex"] == 2]
df_merge = pd.concat([df_male,df_female])
print(df_merge.head())

df = pd.melt(df,
             id_vars=['class','age','sex'],
             value_vars=['steroid','antivirals'],
             var_name='features',
             value_name='values')

df = df.pivot_table(index=['class','age','sex'],
              columns='features',
              values='values',
              aggfunc='first').reset_index()
print(df.head())
# Out:
#    class  age  sex steroid  antivirals fatigue malaise anorexia liver_big  \
# 0      1   51    1       1           2       1       2        1         2
# 2      2   50    1       1           2       1       2        2         1
# 3      2   78    1       2           2       1       2        2         2
# 4      2   31    1       ?           1       2       2        2         2
# 5      2   34    1       2           2       2       2        2         2
#
#   liver_firm spleen_palpable spiders ascites varices bilirubin  \
# 0          2               1       1       2       2         ?
# 2          2               2       2       2       2      0.90
# 3          2               2       2       2       2      0.70
# 4          2               2       2       2       2      0.70
# 5          2               2       2       2       2      1.00
#
#   alk_phosphatase sgot albumin protime  histology
# 0               ?    ?       ?       ?          1
# ...
