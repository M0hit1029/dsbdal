# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

URL = "https://webscraper.io/test-sites/e-commerce/static/computers/laptops"

# 1. Fetch & parse
soup = BeautifulSoup(requests.get(URL).text, "html.parser")

# 2. Loop products and build rows
rows = []
for p in soup.find_all("div", class_="thumbnail"):
    rows.append({
        "Customer Name": p.find("a", class_="title").text.strip(),
        "Rating":        f"{len(p.find_all('span', class_='ws-icon'))} stars",
        "Comment":       p.find("p", class_="description").text.strip(),
        "Comment Tags":  p.find("h4", class_="price").text.strip(),
        "Review Count":  p.find("p", class_="review-count").text.strip()
    })
# 3. Save
df = pd.DataFrame(rows)
df.to_csv("ecommerce_reviews.csv", index=False)
print(df)
print("\nSaved", len(df), "products")
# Out:
#     Customer Name   Rating                                            Comment  \
# 0  Packard 255 G2  2 stars  15.6", AMD E2-3800 1.3GHz, 4GB, 500GB, Windows...
# 1   Aspire E1-510  3 stars    15.6", Pentium N3520 2.16GHz, 4GB, 500GB, Linux
# 2  ThinkPad T540p  1 stars   15.6", Core i5-4200M, 4GB, 500GB, Win7 Pro 64bit
# 3         ProBook  4 stars    14", Core i5 2.6GHz, 4GB, 500GB, Win7 Pro 64bit
# 4   ThinkPad X240  3 stars  12.5", Core i5-4300U, 8GB, 240GB SSD, Win7 Pro...
# 5  Aspire E1-572G  1 stars  15.6", Core i5-4200U, 8GB, 1TB, Radeon R7 M265...
#
#   Comment Tags Review Count
# 0      $416.99    2 reviews
# 1      $306.99    2 reviews
# 2     $1178.99    2 reviews
# 3      $739.99    8 reviews
# 4     $1311.99   12 reviews
# 5      $581.99    2 reviews
#
# Saved 6 products
